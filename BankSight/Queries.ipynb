# %%
import pandas as pd

# %%
tablename='customer' 
query='select * from ', tablename
query
# Out:
# ('select * from ', 'customer')

# %%
df_customers =pd.read_csv('F:/Education/2026/Guvi/Project/BankSight/Docs/customers.csv')
df_accounts =pd.read_csv('F:/Education/2026/Guvi/Project/BankSight/Docs/accounts.csv')
df_transactions =pd.read_csv('F:/Education/2026/Guvi/Project/BankSight/Docs/transactions.csv')
df_loans =pd.read_csv('F:/Education/2026/Guvi/Project/BankSight/Docs/loans.csv')
df_credit_cards =pd.read_json('F:/Education/2026/Guvi/Project/BankSight/Docs/credit_cards.json')
df_branches =pd.read_csv('F:/Education/2026/Guvi/Project/BankSight/Docs/branches.csv')
df_support_tickets =pd.read_csv('F:/Education/2026/Guvi/Project/BankSight/Docs/support_tickets.csv')

#df_customers.info()

# %%
df_customers.isnull().sum()
# Out:
# customer_id     0
# name            0
# gender          0
# age             0
# city            0
# account_type    0
# join_date       0
# dtype: int64

# %%
df_accounts.isnull().sum()
# Out:
# customer_id        0
# account_balance    0
# last_updated       0
# dtype: int64

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Rajaram25*"
)
cursor = conn.cursor()
cursor.execute("CREATE DATABASE IF NOT EXISTS banksight")
print("✅ Database created or already exists.")
cursor.execute("USE banksight")
# Out:
# ✅ Database created or already exists.

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS customers (
    customer_id VARCHAR(50) PRIMARY KEY,
    name VARCHAR(50),
    gender CHAR(1),
    age INT,
    city VARCHAR(50),
    account_type VARCHAR(20),
    join_date DATE
)
""")
conn.commit()
print("✅ customers table created successfully.")
# Out:
# ✅ customers table created successfully.

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS accounts (
     customer_id     VARCHAR(50) ,
     account_balance     float,
     last_updated    datetime    
  )

""")
conn.commit()
print("✅ accounts table created successfully.")
# Out:
# ✅ accounts table created successfully.

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS transactions (
   txn_id    VARCHAR(50)  PRIMARY KEY,
    customer_id    VARCHAR(50),
    txn_type   VARCHAR(50),
    amount   float,
    txn_time   datetime,
    status   VARCHAR(50)
    
)""")
conn.commit()
print("✅ transactions table created successfully.")
# Out:
# ✅ transactions table created successfully.

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS loans (
     Loan_ID      int primary key ,
     customer_id int ,
     Account_ID     int,
     Branch VARCHAR(50),
     Loan_Type  VARCHAR(50),
     Loan_Amount int,
     Interest_Rate float,
     Loan_Term_Months  int ,
     Start_Date  date,
     End_Date  date,
     Loan_Status  VARCHAR(50)
  )
""")
conn.commit()
print("✅ loans table created successfully.")
# Out:
# ✅ loans table created successfully.

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS credit_cards (
     Card_ID     int primary key ,
    customer_id VARCHAR(50) ,
     Account_ID     int,
     Branch VARCHAR(50),
     Card_Number VARCHAR(50),
     Card_Type VARCHAR(50),
     Card_Network VARCHAR(50),
     Credit_Limit int ,
     Current_Balance float,
     Issued_Date date,
     Expiry_Date date,
     Status VARCHAR(50)
  ) """)
conn.commit()
print("✅ credit_cards table created successfully.")
# Out:
# ✅ credit_cards table created successfully.

# %%
Branch_ID,Branch_Name,City,Manager_Name,Total_Employees,Branch_Revenue,Opening_Date,Performance_Rating
1,"Wang, Mcdonald and Church Branch",Kellitown,Kevin Jones,141,16849288.09,2008-08-01,2

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS branches (
    Branch_ID   int  PRIMARY KEY,
    Branch_Name   VARCHAR(50),
    City  VARCHAR(50),
    Manager_Name  VARCHAR(50),
    Total_Employees  int,
    Branch_Revenue  float,
    Opening_Date  DATE,
    Performance_Rating int 
    
)""")
conn.commit()
print("✅ branches table created successfully.")
# Out:
# ✅ branches table created successfully.

# %%
cursor.execute("""   
CREATE TABLE IF NOT EXISTS support_tickets (
     Ticket_ID        VARCHAR(50) primary key ,
     Customer_ID  VARCHAR(50),
     Account_ID      VARCHAR(50),
     Loan_ID  VARCHAR(50),
     Branch_Name   VARCHAR(50),
     Issue_Category  VARCHAR(50),
     Description  VARCHAR(50),
     Date_Opened   date ,
     Date_Closed   date,
     Priority  VARCHAR(50),
     Status   VARCHAR(50),
     Resolution_Remarks  VARCHAR(50),
     Support_Agent   VARCHAR(50),
     Channel    VARCHAR(50),
     Customer_Rating  int    
     
  )""")
conn.commit()
print("✅ branches table created successfully.")
# Out:
# ✅ branches table created successfully.

# %%
for _, row in df_customers.iterrows():
    cursor.execute("""
        INSERT INTO customers (customer_id, name, gender, age, city, account_type, join_date)
        VALUES (%s, %s, %s, %s, %s, %s, %s)
    """, (row['customer_id'], row['name'], row['gender'], row['age'], row['city'], row['account_type'], row['join_date']))

conn.commit()
print("✅ Customers table values inserted successfully.")

# %%
df_accounts
# Out:
#     customer_id  account_balance         last_updated
# 0         C0001        293729.87  2025-05-24 09:46:29
# 1         C0002        150735.15  2025-05-24 09:46:29
# 2         C0003        170156.21  2025-05-24 09:46:29
# 3         C0004        311383.96  2025-05-24 09:46:29
# 4         C0005         60320.75  2025-05-24 09:46:29
# ..          ...              ...                  ...
# 495       C0496        149135.80  2025-05-24 09:46:29
# 496       C0497        376153.36  2025-05-24 09:46:29
# 497       C0498        320254.17  2025-05-24 09:46:29
# 498       C0499        484758.19  2025-05-24 09:46:29
# 499       C0500        454127.94  2025-05-24 09:46:29
#
# [500 rows x 3 columns]

# %%
for _, row in df_accounts.iterrows():
    cursor.execute(""" INSERT INTO accounts (customer_id, account_balance, last_updated) VALUES (%s, %s, %s)
    """, (row['customer_id'], row['account_balance'], row['last_updated']))
print("✅ accounts table values inserted successfully.")
conn.commit()
# Out:
# ✅ Accounts table values inserted successfully.

# %%
df_transactions.columns
# Out:
# Index(['txn_id', 'customer_id', 'txn_type', 'amount', 'txn_time', 'status'], dtype='object')

# %%
for _, row in df_transactions.iterrows():
    cursor.execute(""" INSERT INTO transactions (txn_id, customer_id, txn_type,amount,txn_time,status) VALUES 
    (%s, %s, %s,%s, %s, %s)""", (row['txn_id'], row['customer_id'], row['txn_type'],row['amount'], row['txn_time'], row['status']))
print("✅ transactions table values inserted successfully.")
conn.commit()
# Out:
# ✅ transactions table values inserted successfully.

# %%
for _, row in df_loans.iterrows():
    cursor.execute(""" INSERT INTO loans (Loan_ID, Customer_ID, Account_ID,Branch,Loan_Type,Loan_Amount,Interest_Rate,Loan_Term_Months,Start_Date,End_Date,Loan_Status) VALUES 
    (%s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s)""", (row['Loan_ID'], row['Customer_ID'], row['Account_ID'],row['Branch'], row['Loan_Type'], row['Loan_Amount'],
    row['Interest_Rate'], row['Loan_Term_Months'], row['Start_Date'],row['End_Date'], row['Loan_Status']))
print("✅ loans table values inserted successfully.")
conn.commit()
# Out:
# ✅ loans table values inserted successfully.

# %%
for _, row in df_credit_cards.iterrows():
    cursor.execute(""" INSERT INTO credit_cards (Card_ID, Customer_ID, Account_ID,Branch,Card_Number,Card_Type,Card_Network,
                   Credit_Limit,Current_Balance,Issued_Date,Expiry_Date,Status) VALUES 
    (%s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s)""", (row['Card_ID'], row['Customer_ID'], row['Account_ID'],row['Branch'],
    row['Card_Number'], row['Card_Type'], row['Card_Network'],row['Credit_Limit'], row['Current_Balance'],
    row['Issued_Date'],row['Expiry_Date'], row['Status']))
print("✅ credit_cards table values inserted successfully.")
conn.commit()
# Out:
# ✅ credit_cards table values inserted successfully.

# %%
for _, row in df_branches.iterrows():
    cursor.execute(""" INSERT INTO branches (Branch_ID, Branch_Name, City,Manager_Name,Total_Employees,Branch_Revenue,Opening_Date) 
    VALUES (%s, %s, %s,%s, %s, %s,%s)""", (row['Branch_ID'], row['Branch_Name'], row['City'],row['Manager_Name'],
    row['Total_Employees'], row['Branch_Revenue'], row['Opening_Date']))
print("✅ Branches table values inserted successfully.")
conn.commit()
# Out:
# ✅ Branches table values inserted successfully.

# %%
df_support_tickets.columns
# Out:
# Index(['Ticket_ID', 'Customer_ID', 'Account_ID', 'Loan_ID', 'Branch_Name',
#        'Issue_Category', 'Description', 'Date_Opened', 'Date_Closed',
#        'Priority', 'Status', 'Resolution_Remarks', 'Support_Agent', 'Channel',
#        'Customer_Rating'],
#       dtype='object')

# %%
import numpy as np

df_support_tickets = df_support_tickets.replace({np.nan: None})
df_support_tickets
# Out:
#     Ticket_ID Customer_ID Account_ID Loan_ID  \
# 0      T00001       C0478      A1825    None
# 1      T00002       C0443      A3583    None
# 2      T00003       C0057      A2616   442.0
# 3      T00004       C0301      A8786    None
# 4      T00005       C0238      A3734    None
# ..        ...         ...        ...     ...
# 595    T00596       C0303      A9594    None
# 596    T00597       C0480      A5144    None
# 597    T00598       C0270      A7108   427.0
# 598    T00599       C0144      A4959   121.0
# 599    T00600       C0076      A7140    24.0
#
#                              Branch_Name                 Issue_Category  \
# 0                 Gonzalez-Martin Branch             Loan Payment Delay
# 1                Baldwin and Sons Branch               Loan Foreclosure
# 2      Porter, Osborne and Mendez Branch          Interest Rate Dispute
# 3    Stafford, Oneal and Williams Branch  Mismatch in Account Statement
# ...

# %%
for _, row in df_support_tickets.iterrows():
    cursor.execute(""" INSERT INTO support_tickets (Ticket_ID, Customer_ID, Account_ID, Loan_ID, Branch_Name,
       Issue_Category, Description, Date_Opened, Date_Closed,
       Priority, Status, Resolution_Remarks, Support_Agent, Channel,
       Customer_Rating) 
    VALUES (%s, %s, %s,%s, %s, %s, %s, %s,%s, %s,%s, %s, %s,%s, %s)""", (
    row['Ticket_ID'], row['Customer_ID'], row['Account_ID'],row['Loan_ID'],row['Branch_Name'], row['Issue_Category'], 
    row['Description'], row['Date_Opened'], row['Date_Closed'],row['Priority'],row['Status'], row['Resolution_Remarks'], 
    row['Support_Agent'], row['Channel'], row['Customer_Rating'] ))
print("✅ Support_tickets table values inserted successfully.")
conn.commit()
# Out:
# ✅ Support_tickets table values inserted successfully.

# %%
#How many customers exist per city, and what is their average account balance?
cursor.fetchall()
selectQuery=""" SELECT c.city,count(c.name), avg(a.account_balance) FROM banksight.customers c
join banksight.accounts a on a.customer_id=c.customer_id
group by c.city 
order by c.city """
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('Adamtown', 1, 45424.109375)
# ('Alanton', 1, 392508.78125)
# ('Albertchester', 1, 387844.65625)
# ('Alexanderstad', 1, 383016.75)
# ('Alexfurt', 1, 403292.1875)
# ('Allisonville', 1, 390939.5)
# ('Amandaberg', 1, 476044.53125)
# ('Amandabury', 1, 456395.40625)
# ('Andersonburgh', 1, 284738.5625)
# ('Angelaburgh', 1, 427514.03125)
# ('Angelatown', 1, 200877.296875)
# ('Annaview', 1, 245645.8125)
# ('Anneville', 1, 211699.046875)
# ('Antonioborough', 1, 206241.859375)
# ('Ashleychester', 1, 262278.5)
# ('Ashleyport', 1, 245870.359375)
# ('Ashleyside', 1, 316096.8125)
# ('Ballardburgh', 1, 7639.93017578125)
# ('Banksside', 1, 183200.640625)
# ('Barbermouth', 1, 46322.21875)
# ('Bellport', 1, 453760.71875)
# ('Berryberg', 1, 441088.53125)
# ('Blakefort', 1, 417005.9375)
# ('Bobbyhaven', 1, 482746.375)
# ('Brandonstad', 1, 423341.84375)
# ('Brendachester', 1, 150338.078125)
# ('Brettport', 1, 368131.1875)
# ('Brettstad', 1, 434657.28125)
# ('Bridgetmouth', 1, 344998.0)
# ...

# %%
#Q2: Which account type (Savings, Current, Loan, etc.) holds the highest total balance?
cursor.fetchall()
selectQuery="""
SELECT    
  c.account_type,    sum(a.account_balance) FROM customers c
JOIN accounts a    ON c.customer_id = a.customer_id
    group by c.account_type  
    order by sum(a.account_balance) desc  limit 1
   """
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('Current', 59834705.12963867)

# %%
#Q3: Who are the top 10 customers by total account balance across all account types?
cursor.fetchall()
selectQuery="""SELECT    
  c.customer_id, c.name,
    a.account_balance
FROM customers c
JOIN accounts a
    ON c.customer_id = a.customer_id
order by a.account_balance desc
limit 10"""
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('C0314', 'Amy Nguyen', 498740.0)
# ('C0111', 'Lisa Russell', 497041.0)
# ('C0392', 'Amber Williams', 494780.0)
# ('C0077', 'Audrey Peck', 494700.0)
# ('C0499', 'Alvin Compton', 484758.0)
# ('C0338', 'Sharon Bennett DVM', 482746.0)
# ('C0317', 'Denise Campbell', 481747.0)
# ('C0220', 'Jeffrey Smith', 481568.0)
# ('C0146', 'Ann Crosby', 479706.0)
# ('C0131', 'Emily Lawrence', 479403.0)

# %%
#Q4: Which customers opened accounts in 2023 with a balance above ₹1,00,000?
cursor.fetchall()
selectQuery="""SELECT    
  c.customer_id,c.name,
    a.account_balance
FROM customers c
JOIN accounts a
    ON c.customer_id = a.customer_id
    where YEAR(c.join_date) = 2023 and a.account_balance>100000
    order by a.account_balance desc """
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('C0077', 'Audrey Peck', 494700.0)
# ('C0499', 'Alvin Compton', 484758.0)
# ('C0317', 'Denise Campbell', 481747.0)
# ('C0208', 'Mr. Jimmy Gonzales MD', 476045.0)
# ('C0411', 'Brendan Williams', 466808.0)
# ('C0386', 'Manuel Martinez', 465702.0)
# ('C0383', 'Sara Hunt', 463859.0)
# ('C0286', 'Joshua Torres', 463831.0)
# ('C0068', 'Lisa Gilbert', 460904.0)
# ('C0355', 'Rodney Anthony', 459053.0)
# ('C0325', 'Tiffany Conner', 457722.0)
# ('C0189', 'Chad Murphy', 455366.0)
# ('C0500', 'Emily Brooks', 454128.0)
# ('C0232', 'Peter Bolton', 449801.0)
# ('C0102', 'Crystal Mckenzie', 446110.0)
# ('C0327', 'David Jones', 438400.0)
# ('C0262', 'Janet Saunders', 434937.0)
# ('C0226', 'Kelly Kennedy', 430296.0)
# ('C0346', 'Michelle Sanchez', 414976.0)
# ('C0453', 'Kristen Henderson', 414405.0)
# ('C0450', 'Joseph Walton Jr.', 414122.0)
# ('C0489', 'Andrea Austin', 407686.0)
# ('C0448', 'Randall Martin', 403953.0)
# ('C0053', 'Krystal Chaney', 402963.0)
# ('C0478', 'Ryan Jackson', 400752.0)
# ...

# %%
#Q5: What is the total transaction volume (sum of amounts) by transaction type?

cursor.fetchall()
selectQuery="""select txn_type,sum(amount) from banksight.transactions 
group by txn_type"""
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('deposit', 197574827.52931213)
# ('withdrawal', 151387322.34135437)
# ('transfer', 50592799.70474243)
# ('online fraud', 23829502.21949768)
# ('purchase', 73834033.57324219)

# %%
#Q6: How many failed transactions occurred for each transaction type?
cursor.fetchall()
selectQuery="""select txn_type,count(status) from banksight.transactions 
where status='failed'
group by txn_type"""
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('online fraud', 489)
# ('deposit', 433)
# ('withdrawal', 314)
# ('purchase', 167)
# ('transfer', 94)

# %%
#Q7: What is the total number of transactions per transaction type?
cursor.fetchall()
selectQuery="""select txn_type,count(status) TransactionCount from banksight.transactions 
#where status!='failed'
group by txn_type"""
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('deposit', 3921)
# ('withdrawal', 3065)
# ('transfer', 1012)
# ('online fraud', 489)
# ('purchase', 1513)

# %%
#Q8: Which accounts have 5 or more high-value transactions above ₹20,000?
cursor.fetchall()
selectQuery="""select customer_id, count(*) from banksight.transactions where amount > 20000  
AND status = 'success'
group by customer_id HAVING COUNT(*) >= 5
order by count(*) desc"""
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('C0124', 27)
# ('C0444', 26)
# ('C0398', 25)
# ('C0379', 23)
# ('C0481', 23)
# ('C0223', 23)
# ('C0332', 22)
# ('C0496', 22)
# ('C0412', 22)
# ('C0322', 21)
# ('C0126', 21)
# ('C0053', 21)
# ('C0040', 21)
# ('C0289', 21)
# ('C0325', 21)
# ('C0466', 20)
# ('C0180', 20)
# ('C0408', 20)
# ('C0471', 20)
# ('C0206', 20)
# ('C0343', 20)
# ('C0298', 20)
# ('C0119', 20)
# ('C0318', 20)
# ('C0063', 20)
# ('C0293', 20)
# ('C0248', 20)
# ('C0360', 20)
# ('C0409', 20)
# ('C0093', 19)
# ('C0025', 19)
# ('C0101', 19)
# ('C0068', 19)
# ('C0038', 19)
# ('C0371', 19)
# ('C0353', 19)
# ('C0074', 19)
# ('C0400', 19)
# ('C0375', 19)
# ('C0287', 19)
# ('C0218', 19)
# ('C0019', 19)
# ('C0243', 19)
# ('C0461', 19)
# ('C0331', 19)
# ('C0054', 19)
# ('C0258', 19)
# ('C0363', 18)
# ('C0460', 18)
# ('C0476', 18)
# ('C0201', 18)
# ('C0290', 18)
# ('C0299', 18)
# ('C0267', 18)
# ('C0199', 18)
# ('C0183', 18)
# ('C0311', 18)
# ('C0055', 18)
# ('C0020', 18)
# ('C0167', 18)
# ('C0468', 18)
# ('C0296', 18)
# ...

# %%
#Q9: What is the average loan amount and interest rate by loan type (Personal, Auto, Home, etc.)?
cursor.fetchall()
selectQuery="""select Loan_Type, avg(Loan_Amount), round(avg(Interest_Rate),2) from banksight.loans
group by Loan_Type"""
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('Personal', Decimal('2461543.7478'), 10.46)
# ('Business', Decimal('2793968.8738'), 10.63)
# ('Auto', Decimal('2399260.9813'), 10.53)
# ('Home', Decimal('2344576.6612'), 10.87)
# ('Education', Decimal('2393947.7009'), 10.11)

# %%
#Q10: Which customers currently hold more than one active or approved loan?
cursor.fetchall()
selectQuery="""select customer_id, count(*) from banksight.loans
 where Loan_Status in ('Active','Approved')
 group by customer_id having count(*)>1"""
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# (1411, 3)
# (1383, 3)
# (1073, 2)
# (1059, 2)
# (1430, 2)
# (1292, 3)
# (1216, 2)
# (1359, 2)
# (1231, 4)
# (1155, 2)
# (1020, 2)
# (1249, 3)
# (1088, 3)
# (1462, 2)
# (1146, 2)
# (1531, 2)
# (1565, 2)
# (1481, 2)
# (1101, 2)
# (1180, 3)
# (1317, 2)
# (1378, 2)
# (1551, 2)
# (1460, 2)
# (1470, 3)
# (1455, 3)
# (1126, 2)
# (1580, 2)
# (1488, 3)
# (1549, 2)
# (1408, 2)
# (1325, 3)
# (1528, 2)
# (1587, 2)
# (1405, 2)
# (1308, 2)
# (1386, 2)
# (1209, 2)
# (1275, 2)
# (1236, 2)
# (1363, 2)
# (1108, 2)
# (1502, 3)
# (1010, 4)
# (1284, 2)
# (1162, 2)
# (1123, 2)
# (1382, 3)
# (1263, 2)
# (1420, 2)
# (1132, 2)
# (1364, 2)
# (1005, 2)
# (1270, 2)
# (1495, 2)
# (1255, 2)

# %%
#Q11: Who are the top 5 customers with the highest outstanding (non-closed) loan amounts?
cursor.fetchall()
selectQuery="""select   customer_id, sum(Loan_Amount) from  banksight.loans  
where Loan_Status != 'Closed'
group by customer_id
order by sum(Loan_Amount) desc
limit 5"""
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# (1455, Decimal('15389458'))
# (1383, Decimal('13279523'))
# (1088, Decimal('11960853'))
# (1236, Decimal('11783260'))
# (1010, Decimal('11747032'))

# %%
#Q12: What is the average loan amount per branch?

cursor.fetchall()
selectQuery="""select Branch, count(*),avg(Loan_Amount) FROM banksight.loans
group by Branch order by Branch"""
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('Acosta, Murphy and Rojas Branch', 3, Decimal('1525891.0000'))
# ('Adams LLC Branch', 2, Decimal('4362487.0000'))
# ('Adams, Mitchell and Schneider Branch', 1, Decimal('899686.0000'))
# ('Aguirre-Bowman Branch', 1, Decimal('3045520.0000'))
# ('Allen-Guzman Branch', 1, Decimal('4339134.0000'))
# ('Allen, Martin and Mosley Branch', 1, Decimal('2486493.0000'))
# ('Anderson-Barnes Branch', 1, Decimal('2275202.0000'))
# ('Anderson-Dunn Branch', 2, Decimal('4473898.0000'))
# ('Andrews Ltd Branch', 1, Decimal('250573.0000'))
# ('Andrews-Marquez Branch', 1, Decimal('921987.0000'))
# ('Austin, Rogers and Ayala Branch', 2, Decimal('2451570.5000'))
# ('Baldwin and Sons Branch', 1, Decimal('2308172.0000'))
# ('Barnes PLC Branch', 1, Decimal('4051928.0000'))
# ('Barton PLC Branch', 2, Decimal('1514849.5000'))
# ('Beasley-Kirk Branch', 1, Decimal('4022163.0000'))
# ('Beck, Howe and Perry Branch', 1, Decimal('4667891.0000'))
# ('Bell PLC Branch', 1, Decimal('3777178.0000'))
# ...

# %%
#Q13: How many customers exist in each age group (e.g., 18–25, 26–35, etc.)?
cursor.fetchall()
selectQuery="""select 
case 
  WHEN age BETWEEN 18 AND 25 THEN '18-25'
        WHEN age BETWEEN 26 AND 35 THEN '26-35'
        WHEN age BETWEEN 36 AND 45 THEN '36-45'
        WHEN age BETWEEN 46 AND 60 THEN '46-60'
        ELSE '60+'
END AS age_group,
COUNT(*) AS customer_count
 FROM banksight.customers 
 group by age_group"""
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('60+', 95)
# ('36-45', 101)
# ('46-60', 150)
# ('26-35', 75)
# ('18-25', 79)

# %%
 #Q14: Which issue categories have the longest average resolution time?
 
cursor.fetchall()
selectQuery="""select Issue_Category, avg(DATEDIFF(Date_Closed,Date_Opened)) AS AvgResultion from banksight.support_tickets
 group by Issue_Category
 order by AvgResultion desc"""
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('Card Not Working', Decimal('18.5000'))
# ('Mismatch in Account Statement', Decimal('17.9032'))
# ('Debit Card Delivery Delay', Decimal('17.8148'))
# ('UPI Payment Failed', Decimal('17.4583'))
# ('Account Closure Request', Decimal('17.3226'))
# ('Account Frozen', Decimal('17.1154'))
# ('Loan Foreclosure', Decimal('16.5833'))
# ('Cheque Bounce', Decimal('16.0000'))
# ('EMI Auto-debit Failed', Decimal('15.9762'))
# ('Online Transfer Failed', Decimal('15.4762'))
# ('KYC Update Required', Decimal('15.4074'))
# ('Interest Rate Dispute', Decimal('15.3103'))
# ('Account Access Issue', Decimal('14.8846'))
# ('Loan Payment Delay', Decimal('14.7115'))
# ('Unauthorized Transaction', Decimal('13.1071'))

# %%
#Q15: Which support agents have resolved the most critical tickets with high customer ratings (≥4)?
cursor.fetchall()
selectQuery="""SELECT Support_Agent,    COUNT(*) AS Count FROM banksight.support_tickets
WHERE Priority = 'Critical'   AND Status IN ('Closed', 'Resolved')  AND Customer_Rating >= 4
GROUP BY Support_Agent
ORDER BY Count DESC """
cursor.execute(selectQuery)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('Gabriel Mutti', 3)
# ('Owen Mahajan', 3)
# ('Chanakya Natt', 3)
# ('Wishi Chhabra', 2)
# ('Veda Samra', 2)
# ('Wriddhish Sarraf', 2)
# ('Vansha Sood', 2)
# ('Udyati Mody', 1)
# ('Ekanta Devan', 1)
# ('Rehaan Balakrishnan', 1)
# ('Harish Anne', 1)
# ('Aarnav Sangha', 1)
# ('Chaitaly Vaidya', 1)
# ('Ikbal Sidhu', 1)
# ('Ekani Oza', 1)
# ('Ria Ghose', 1)
# ('Advik Bhagat', 1)
